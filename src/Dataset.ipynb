# %%
import pandas as pd

# %%
nyc = pd.read_csv("NYC.csv") #Importing data set

# %%
nyc.head()                   #Checking top 5 rows of the data sets
# Out:
#       CAMIS            DBA       BORO BUILDING             STREET  ZIPCODE  \
# 0  50130090      CITY CHIK  Manhattan      230        PARK AVENUE  10169.0
# 1  50102324            NaN   Brooklyn       98  NORTH   11 STREET  11249.0
# 2  50140834            NaN      Bronx     1576      WATSON AVENUE  10472.0
# 3  50139187            NaN     Queens     3812           30TH AVE  11103.0
# 4  50140402  LOBSTER PLACE  Manhattan       75           9 AVENUE  10011.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE ACTION  ... Census Tract  \
# 0  9175650578                 NaN      01/01/1900    NaN  ...       9200.0
# 1  7162191479                 NaN      01/01/1900    NaN  ...      55700.0
# 2  3473276655                 NaN      01/01/1900    NaN  ...       5001.0
# 3  3476180399                 NaN      01/01/1900    NaN  ...      15500.0
# 4  2122555072                 NaN      01/01/1900    NaN  ...       8300.0
#
#          BIN           BBL   NTA Location Point1 Zip Codes  \
# ...

# %%
nyc.tail(3)                  #Checking last 3 rows of the data sets
# Out:
#            CAMIS              DBA       BORO BUILDING          STREET  \
# 204776  50088737  ANGELINA BAKERY  Manhattan      575        8 AVENUE
# 204777  41449514       PURPLE YAM   Brooklyn     1314  CORTELYOU ROAD
# 204778  50038543  LA PALAPA TACOS  Manhattan      230     PARK AVENUE
#
#         ZIPCODE       PHONE       CUISINE DESCRIPTION INSPECTION DATE  \
# 204776  10018.0  9172614534  Bakery Products/Desserts      05/18/2022
# 204777  11226.0  7189408188                      Thai      11/10/2022
# 204778  10169.0  6467470815                   Tex-Mex      10/31/2022
#
#                                                  ACTION  ... Census Tract  \
# 204776  Violations were cited in the following area(s).  ...      11500.0
# 204777  Violations were cited in the following area(s).  ...      52000.0
# 204778  Violations were cited in the following area(s).  ...       9200.0
#
#               BIN           BBL   NTA Location Point1 Zip Codes  \
# ...

# %%
nyc.describe()               #Checking basic parameters of data set like count, mean etc
# Out:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.047790e+05  202065.000000  195292.000000  204521.000000
# mean   4.750154e+07   10707.780373      22.560013      40.187643
# std    4.051339e+06     594.166896      17.424827       4.655750
# min    3.007544e+07    8512.000000       0.000000       0.000000
# 25%    4.163963e+07   10023.000000      11.000000      40.682964
# 50%    5.006447e+07   11101.000000      18.000000      40.730345
# 75%    5.010557e+07   11231.000000      30.000000      40.761156
# max    5.014166e+07   12345.000000     168.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  204521.000000    201528.000000     201524.000000  201524.000000
# mean      -72.961993       254.353082         20.801259   30121.925468
# std         8.452104       129.892218         15.793059   31585.262774
# min       -74.249101       101.000000          1.000000     100.000000
# ...

# %%
nyc.info()                   #Checking info like number of columns, datatype of col etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204779 entries, 0 to 204778
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CAMIS                   204779 non-null  int64
#  1   DBA                     204290 non-null  object
#  2   BORO                    204779 non-null  object
#  3   BUILDING                204468 non-null  object
#  4   STREET                  204773 non-null  object
#  5   ZIPCODE                 202065 non-null  float64
#  6   PHONE                   204772 non-null  object
#  7   CUISINE DESCRIPTION     202460 non-null  object
#  8   INSPECTION DATE         204779 non-null  object
#  9   ACTION                  202460 non-null  object
#  10  VIOLATION CODE          201328 non-null  object
#  11  VIOLATION DESCRIPTION   201328 non-null  object
#  12  CRITICAL FLAG           204779 non-null  object
#  13  SCORE                   195292 non-null  float64
# ...
